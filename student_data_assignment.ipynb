# %%
import pandas as pd

df=pd.read_csv("/content/student-por.csv")
df
# Out:
#     school sex  age address famsize Pstatus  Medu  Fedu      Mjob      Fjob  \
# 0       GP   F   18       U     GT3       A     4     4   at_home   teacher
# 1       GP   F   17       U     GT3       T     1     1   at_home     other
# 2       GP   F   15       U     LE3       T     1     1   at_home     other
# 3       GP   F   15       U     GT3       T     4     2    health  services
# 4       GP   F   16       U     GT3       T     3     3     other     other
# ..     ...  ..  ...     ...     ...     ...   ...   ...       ...       ...
# 644     MS   F   19       R     GT3       T     2     3  services     other
# 645     MS   F   18       U     LE3       T     3     1   teacher  services
# 646     MS   F   18       U     GT3       T     1     1     other     other
# 647     MS   M   17       U     LE3       T     3     1  services  services
# 648     MS   M   18       R     LE3       T     3     2  services     other
#
# ...

# %%
# check the info of dataset

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 649 entries, 0 to 648
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      649 non-null    object
#  1   sex         649 non-null    object
#  2   age         649 non-null    int64
#  3   address     649 non-null    object
#  4   famsize     649 non-null    object
#  5   Pstatus     649 non-null    object
#  6   Medu        649 non-null    int64
#  7   Fedu        649 non-null    int64
#  8   Mjob        649 non-null    object
#  9   Fjob        649 non-null    object
#  10  reason      649 non-null    object
#  11  guardian    649 non-null    object
#  12  traveltime  649 non-null    int64
#  13  studytime   649 non-null    int64
#  14  failures    649 non-null    int64
#  15  schoolsup   649 non-null    object
#  16  famsup      649 non-null    object
#  17  paid        649 non-null    object
#  18  activities  649 non-null    object
# ...

# %%
# check for null values

# %%
df.isna().sum()
# Out:
# school        0
# sex           0
# age           0
# address       0
# famsize       0
# Pstatus       0
# Medu          0
# Fedu          0
# Mjob          0
# Fjob          0
# reason        0
# guardian      0
# traveltime    0
# studytime     0
# failures      0
# schoolsup     0
# famsup        0
# paid          0
# activities    0
# nursery       0
# higher        0
# internet      0
# romantic      0
# famrel        0
# freetime      0
# goout         0
# Dalc          0
# Walc          0
# health        0
# absences      0
# G1            0
# G2            0
# G3            0
# dtype: int64

# %%
# display columns

df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
#Seggregate data in categorical and continuous type

cat=[]
con=[]

for i in df.columns:
    if df[i].dtypes=='object':
        cat.append(i)
    else:
        con.append(i)

# %% [markdown]
# **Display categorical values**

# %%
cat
# Out:
# ['school',
#  'sex',
#  'address',
#  'famsize',
#  'Pstatus',
#  'Mjob',
#  'Fjob',
#  'reason',
#  'guardian',
#  'schoolsup',
#  'famsup',
#  'paid',
#  'activities',
#  'nursery',
#  'higher',
#  'internet',
#  'romantic']

# %% [markdown]
# **Display continuous value**

# %%
con
# Out:
# ['age',
#  'Medu',
#  'Fedu',
#  'traveltime',
#  'studytime',
#  'failures',
#  'famrel',
#  'freetime',
#  'goout',
#  'Dalc',
#  'Walc',
#  'health',
#  'absences',
#  'G1',
#  'G2',
#  'G3']

# %% [markdown]
# **categorical columns type and bar chart**

# %%
df['guardian'].value_counts()
# Out:
# guardian
# mother    455
# father    153
# other      41
# Name: count, dtype: int64

# %%
df['paid'].value_counts()
# Out:
# paid
# no     610
# yes     39
# Name: count, dtype: int64

# %%
df['paid'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='paid'>

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(6,3))

sns.countplot(df['guardian'])
plt.title('Countplot of guradian')
plt.show()

# %%
# pie chart for guradian


a=df['guardian'].value_counts()
a

plt.pie(a, labels=a.index, autopct="%0.01f%%")
plt.show()

# %% [markdown]
# **Continuous values**

# %%
plt.figure(figsize=(6,5))
plt.hist(df['health'], bins= 10,edgecolor='black')
plt.show()

# %%
plt.figure(figsize=(6,5))
plt.hist(df['age'], bins= 10,edgecolor='darkblue')
plt.xlabel("age")
plt.ylabel('count og age')
plt.show()

# %% [markdown]
#  **pie chart for continuous value**

# %%
a=df['traveltime'].value_counts()
a

plt.pie(a,labels=a.index,autopct="%d%%")
plt.show()

# %% [markdown]
# **correlation**

# %%
df[['studytime','traveltime']].corr()
# Out:
#             studytime  traveltime
# studytime    1.000000   -0.063154
# traveltime  -0.063154    1.000000

# %%
df[con].corr()
# Out:
#                  age      Medu      Fedu  traveltime  studytime  failures  \
# age         1.000000 -0.107832 -0.121050    0.034490  -0.008415  0.319968
# Medu       -0.107832  1.000000  0.647477   -0.265079   0.097006 -0.172210
# Fedu       -0.121050  0.647477  1.000000   -0.208288   0.050400 -0.165915
# traveltime  0.034490 -0.265079 -0.208288    1.000000  -0.063154  0.097730
# studytime  -0.008415  0.097006  0.050400   -0.063154   1.000000 -0.147441
# failures    0.319968 -0.172210 -0.165915    0.097730  -0.147441  1.000000
# famrel     -0.020559  0.024421  0.020256   -0.009521  -0.004127 -0.062645
# freetime   -0.004910 -0.019686  0.006841    0.000937  -0.068829  0.108995
# goout       0.112805  0.009536  0.027690    0.057454  -0.075442  0.045078
# Dalc        0.134768 -0.007018  0.000061    0.092824  -0.137585  0.105949
# Walc        0.086357 -0.019766  0.038445    0.057007  -0.214925  0.082266
# health     -0.008750  0.004614  0.044910   -0.048261  -0.056433  0.035588
# ...

# %%
sns.boxplot(x='health',y='age',data=df)
plt.show()

# %% [markdown]
# **SCATTER PLOT OF CONTINUOUS**

# %%
plt.scatter(df['age'],df['health'])

# %% [markdown]
# **SCATTER PLOT OF CATEGORICAL**

# %%
plt.scatter(df['guardian'],df['Mjob'])

# %% [markdown]
# **Categorical v/s categorical**

# %%
pd.crosstab(df['sex'],df['address'])
# Out:
# address    R    U
# sex
# F        120  263
# M         77  189

# %% [markdown]
# **HEAT MAP**

# %%
ct=pd.crosstab(df['sex'],df['address'])
ct
# Out:
# address    R    U
# sex
# F        120  263
# M         77  189

# %%
sns.heatmap(ct,annot=True,cmap='viridis')
# Out:
# <Axes: xlabel='address', ylabel='sex'>

# %% [markdown]
# **continuous v/s categorical**

# %%
sns.boxplot(df,x='school',y='age')
# Out:
# <Axes: xlabel='school', ylabel='age'>

# %% [markdown]
# **continuous/continuous**

# %%
plt.scatter(df['Medu'],df['Fedu'])

# %%
df[['Medu','Fedu']].corr()
# Out:
#           Medu      Fedu
# Medu  1.000000  0.647477
# Fedu  0.647477  1.000000

# %%
ct=pd.crosstab(df['Medu'],df['Fedu'])
ct
# Out:
# Fedu  0   1    2   3   4
# Medu
# 0     1   2    3   0   0
# 1     5  92   36   8   2
# 2     0  52  101  25   8
# 3     0  20   42  54  23
# 4     1   8   27  44  95

# %%
sns.heatmap(ct,annot=True,cmap='coolwarm')
# Out:
# <Axes: xlabel='Fedu', ylabel='Medu'>

# %% [markdown]
# **Pairplot**

# %%
sns.pairplot(df,x_vars=['G1','G2','G3'],y_vars='age')
